# %%
#using norm.rvs library

import scipy.stats
import numpy as np
data = scipy.stats.norm.rvs(size=100000, loc=0, scale=1.5, random_state=123)
hist = np.histogram(data, bins=100)

# %%
#generating with normal distribution

import matplotlib.pyplot as plt
# %matplotlib inline
plt.title("data with normal distribution")
plt.plot(data[0:1000], label='data')
plt.show()

# %%
#plotting histogram

plt.title("histogram")
plt.plot(hist[0], label='histogram')
plt.show()

# %%
hist_dist = scipy.stats.rv_histogram(hist)

# %%
hist_dist.pdf(1.0)
# Out:
# 0.20538577847618705

# %%
 hist_dist.cdf(2.0)
# Out:
# 0.908185685430565

# %%
print(hist_dist.pdf(np.max(data)))
print(hist_dist.cdf(np.max(data)))
print(hist_dist.pdf(np.min(data)))
print(hist_dist.cdf(np.min(data)))
# Out:
# 0.0
# 1.0
# 7.759190724449831e-05
# 0.0

# %%
#generating values to match the histogram

import matplotlib.pyplot as plt
# %matplotlib inline
X = np.linspace(-5.0, 5.0, 100)
plt.title("histogram and PDF from Template")
plt.hist(data, density=True, bins=100)
plt.plot(X, hist_dist.pdf(X), label='PDF')
plt.show()
